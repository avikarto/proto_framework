# %%
import sys
import os
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from dotenv import load_dotenv
load_dotenv()
sys.path.append(os.environ['PROJECT_ROOT'] + '/src')
from time_series.utils import make_ts_data, get_frequencies  # noqa: E402

# %%
# Generate and view time-series data
t_step = 0.01
df = make_ts_data(t_step=t_step, plot=True)

# %%
# Extract strongest freqencies via fourier analysis
get_frequencies(df=df, target='value', n=2, t_step=t_step)
# Out:
# The 2 strongest signals had frequencies [0.4, 0.1]

# %%
# Look at predictions for last 20% of data
df_train = df[:int(len(df)*0.8)]
plt.scatter(df_train['time'], df_train['value'], s=3, c='blue')
df_pred = pd.read_csv(f"{os.environ['PROJECT_ROOT']}/predictions/xgb_predict.csv")
plt.scatter(df_pred['time'], df_pred['value'], s=3, c='red')
plt.show()
